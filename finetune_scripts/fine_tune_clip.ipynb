# %%
import clip
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)

# %%
from sentence_transformers import SentenceTransformer, InputExample, losses, models
from torch.utils.data import DataLoader
from PIL import Image
import os

# Define your traing data
train_data = []
with open('/nobackup/riyad/NAVICLUES/data/image_paths.txt', 'r') as f:
    with open('/nobackup/riyad/NAVICLUES/NaviClues/Navig/guidebook/text_descriptions.txt', 'r') as f2:
        for line in zip(f, f2):
            image_paths = line[0].strip()
            full_paths = os.path.join('/nobackup/riyad/NAVICLUES/data/', image_paths)
            print(f"Loading image from: {full_paths}")
            images = Image.open(full_paths)
            train_data.append( (Image.open(full_paths), line[1].strip()) )



print(f"Total training samples: {len(train_data)}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sentence_transformers import SentenceTransformer, InputExample, losses, models
#       2 from torch.utils.data import DataLoader
#       3 from PIL import Image
#
# ModuleNotFoundError: No module named 'sentence_transformers'
