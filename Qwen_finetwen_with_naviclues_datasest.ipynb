# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!pip install torch transformers peft accelerate bitsandbytes datasets sentencepiece safetensors Pillow

# %%
#download QwenVL-model
# import os
# from huggingface_hub import snapshot_download

# hf_model_id = "Qwen/Qwen2-VL-7B-Instruct"
# # Optional: Enable faster downloads

# # Download model locally to a directory named "Qwen2-VL-7B-Instruct-local"
# local_directory = "./Qwen2-VL-7B"
# snapshot_download(repo_id=hf_model_id, local_dir=local_directory)
# Out:
# Fetching 17 files:   0%|          | 0/17 [00:00<?, ?it/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/3.90G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/244 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# chat_template.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# LICENSE: 0.00B [00:00, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/347 [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/1.09G [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# ...

# %%
# !ls
# Out:
# drive  Qwen2-VL-7B  sample_data

# %%
# %cd drive/MyDrive/Navig/fine_tune
# Out:
# /content/drive/MyDrive/Navig/fine_tune

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Navig/fine_tune

# %%
# !python prepare_sft_data.py
# Out:
# --- STEP 1: Reading /content/drive/MyDrive/Navig/data/NaviClues/filtered_data.jsonl ---
# File loaded. Total lines: 1638

# %%
# !pip install -q transformers accelerate peft bitsandbytes qwen-vl-utils pillow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 45.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 67.2 MB/s eta 0:00:00

# %%
# !python finetune_qwen.py \
    --model_name_or_path /content/drive/MyDrive/Navig/fine_tune/Qwen2-VL-7B \
    --data_path /content/drive/MyDrive/Navig/fine_tune/finetuneqwen.jsonl \
    --output_dir /content/drive/MyDrive/Navig/output \
    --use_lora \
    --num_train_epochs 3 \
    --bf16
# Out:
# 2025-12-11 19:35:42.099999: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-11 19:35:42.118076: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765481742.140153   15136 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765481742.146868   15136 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
