# %% [markdown]
# <a href="https://colab.research.google.com/github/Nick-Boddy/GeolocRAG/blob/main/geovisrag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cd /content/drive/MyDrive/GeoVisRAG

# %%
# !git config --global user.email riyadworku@gmail.com
# !git config --global user.name RiyadHassen

# %%
# !git clone https://github.com/Nick-Boddy/GeolocRAG.git
# Out:
# Cloning into 'GeolocRAG'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
from google.colab import userdata
userdatadrive = userdata.get('GH_TOKEN')

# %% [markdown]
# The previous `git clone` command failed. The error message `fatal: could not read Username for 'https://github.com': No such device or address` can sometimes occur when Git attempts to prompt for credentials in an environment that doesn't support interactive input, even for public repositories. Also, the `!cd` command only applies to the cell it's run in, so the `git clone` was likely attempted in `/content/` instead of `/content/drive/MyDrive/GeoVisRAG`.
#
# I will now create the target directory (if it doesn't already exist), change into it, and then clone the repository.

# %% [markdown]
# Once you have generated a Personal Access Token (PAT) from GitHub and stored it in Colab's secrets manager (e.g., named `GH_TOKEN`), you can use the following code to clone your private repository. Remember to replace `your_github_username` and `your_private_repo` with your actual details.
